# %% [markdown]
# <h1 style='color: green; text-align:center'>Descriptive Analysis: Passenger Satisfaction Dataset - US Airline Passenger Satisfaction</h1>

# %% [markdown]
# <h2 style='color: purple;'>Import libraries and packages</h2>

# %%
import pandas as pd

# %% [markdown]
# <h2 style='color: purple;'>Context</h2>

# %% [markdown]
# US Airline passenger satisfaction survey.

# %% [markdown]
# <h2 style='color: purple;'>Content</h2>

# %% [markdown]
# This dataset consists of 24 features, including:
# - <b>id</b>: unique number foreach respondent.
# - <b>satisfaction</b>: Airline satisfaction level(Satisfaction, neutral or dissatisfaction).
# - <b>Gender</b>: Gender of the passengers (Female or Male).
# - <b>Customer Type</b>: The customer type (Loyal customer or disloyal customer).
# - <b>Age</b>: The actual age of the passengers.
# - <b>Type of Travel</b>: Purpose of the flight of the passengers (Personal Travel or Business Travel).
# - <b>Class</b>: Travel class in the plane of the passengers (Business, Eco, and Eco Plus).
# - <b>Flight distance</b>: The flight distance of this journey.
# - <b>Seat comfort</b>: Satisfaction level of Seat comfort.
# - <b>Departure/Arrival time convenient</b>: Satisfaction level of Departure/Arrival time convenient.
# - <b>Food and drink</b>: Satisfaction level of Food and drink.
# - <b>Gate location</b>: Satisfaction level of Gate location.
# - <b>Inflight wifi service</b>: Satisfaction level of the inflight wifi service (0:Not Applicable; 1-5).
# - <b>Inflight entertainment</b>: Satisfaction level of inflight entertainment.
# - <b>Online support</b>: Satisfaction level of online support.
# - <b>Ease of Online booking</b>: Satisfaction level of online booking.
# - <b>On-board service</b>: Satisfaction level of On-board service.
# - <b>Leg room service</b>: Satisfaction level of Leg room service.
# - <b>Baggage handling</b>: Satisfaction level of baggage handling.
# - <b>Check-in service</b>: Satisfaction level of Check-in service.
# - <b>Cleanliness</b>: Satisfaction level of Cleanliness.
# - <b>Online boarding</b>: Satisfaction level of online boarding.
# - <b>Departure Delay in Minutes</b>: Minutes delayed when departure.
# - <b>Arrival Delay in Minutes</b>: Minutes delayed when Arrival.

# %% [markdown]
# <h2 style='color: purple;'>Dependence Variables</h2>

# %% [markdown]
# - Satisfaction
# - Customer Type
# - Class

# %% [markdown]
# <h2 style='color: purple;'>Independence Variables</h2>

# %% [markdown]
# - id
# - Gender
# - Age
# - Type of Travel
# - Flight Distance
# - Seat comfort
# - Departure/Arrival time convenient
# - Food and drink
# - Gate location
# - Inflight wifi service
# - Inflight entertainment
# - Online support
# - Ease of Online booking
# - On-board service
# - Leg room service
# - Baggage handling
# - Checkin service
# - Cleanliness
# - Online boarding
# - Departure Delay in Minutes
# - Arrival Delay in Minutes

# %% [markdown]
# <h2 style='color: purple;'>Initialize and load dataset</h2>

# %%
airline_passenger_satisfaction = pd.read_csv('dataset/airline_passenger_satisfaction.csv', sep=';')

# %%
pd.set_option('display.max_columns', None)
airline_passenger_satisfaction.head()
# Out:
#        id Satisfaction  Gender   Customer Type  Age   Type of Travel  \
# 0   11112    satisfied  Female  Loyal Customer   65  Personal Travel
# 1  110278    satisfied    Male  Loyal Customer   47  Personal Travel
# 2  103199    satisfied  Female  Loyal Customer   15  Personal Travel
# 3   47462    satisfied  Female  Loyal Customer   60  Personal Travel
# 4  120011    satisfied  Female  Loyal Customer   70  Personal Travel
#
#       Class  Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0       Eco              265             0                                  0
# 1  Business             2464             0                                  0
# 2       Eco             2138             0                                  0
# 3       Eco              623             0                                  0
# 4       Eco              354             0                                  0
#
#    Food and drink  Gate location  Inflight wifi service  \
# ...

# %% [markdown]
# <h2 style='color: purple;'>Describe dataset</h2>

# %% [markdown]
# <h3 style='color: orange'>Number of row and column</h3>

# %%
print('Number of row    :', airline_passenger_satisfaction.shape[0])
print('Number of column :', airline_passenger_satisfaction.shape[1])
# Out:
# Number of row    : 129880
# Number of column : 24

# %% [markdown]
# <h3 style='color: orange'>Information for each feature</h3>

# %% [markdown]
# This dataset consists of three data types, namely 1 float64, 18 int64, and 5 objects.

# %%
airline_passenger_satisfaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
# id                                   129880 non-null int64
# Satisfaction                         129880 non-null object
# Gender                               129880 non-null object
# Customer Type                        129880 non-null object
# Age                                  129880 non-null int64
# Type of Travel                       129880 non-null object
# Class                                129880 non-null object
# Flight Distance                      129880 non-null int64
# Seat comfort                         129880 non-null int64
# Departure/Arrival time convenient    129880 non-null int64
# Food and drink                       129880 non-null int64
# Gate location                        129880 non-null int64
# Inflight wifi service                129880 non-null int64
# Inflight entertainment               129880 non-null int64
# ...

# %%
airline_passenger_satisfaction[airline_passenger_satisfaction['Age'] == 7]
# Out:
#             id             Satisfaction  Gender      Customer Type  Age  \
# 61        9397                satisfied  Female     Loyal Customer    7
# 181     122382                satisfied    Male     Loyal Customer    7
# 194     103705                satisfied  Female     Loyal Customer    7
# 216      65389                satisfied    Male     Loyal Customer    7
# 402     102461                satisfied  Female     Loyal Customer    7
# ...        ...                      ...     ...                ...  ...
# 103541   98357                satisfied    Male     Loyal Customer    7
# 122201   28019                satisfied  Female     Loyal Customer    7
# 129714   95412  neutral or dissatisfied    Male  disloyal Customer    7
# 129835   75030  neutral or dissatisfied  Female  disloyal Customer    7
# 129846  128521  neutral or dissatisfied  Female  disloyal Customer    7
#
#          Type of Travel     Class  Flight Distance  Seat comfort  \
# ...

# %%
airline_passenger_satisfaction[(airline_passenger_satisfaction['Satisfaction'] == 'neutral or dissatisfied') & (airline_passenger_satisfaction['Customer Type'] =='Loyal Customer')]
# Out:
#             id             Satisfaction  Gender   Customer Type  Age  \
# 795     123730  neutral or dissatisfied    Male  Loyal Customer   48
# 799      32873  neutral or dissatisfied    Male  Loyal Customer   30
# 803      87865  neutral or dissatisfied    Male  Loyal Customer   19
# 804      46711  neutral or dissatisfied    Male  Loyal Customer   13
# 805      41931  neutral or dissatisfied    Male  Loyal Customer   31
# ...        ...                      ...     ...             ...  ...
# 110937   96117  neutral or dissatisfied    Male  Loyal Customer   30
# 110945   90791  neutral or dissatisfied  Female  Loyal Customer   28
# 110948   75019  neutral or dissatisfied  Female  Loyal Customer   53
# 110951   63970  neutral or dissatisfied    Male  Loyal Customer   27
# 110954    9522  neutral or dissatisfied  Female  Loyal Customer   53
#
#          Type of Travel     Class  Flight Distance  Seat comfort  \
# 795     Personal Travel  Eco Plus             1201             1
# ...

# %%
airline_passenger_satisfaction[(airline_passenger_satisfaction['Satisfaction'] == 'satisfied') & (airline_passenger_satisfaction['Customer Type'] == 'disloyal Customer')]
# Out:
#             id Satisfaction  Gender      Customer Type  Age   Type of Travel  \
# 39981    37839    satisfied  Female  disloyal Customer   23  Business travel
# 39982    21261    satisfied    Male  disloyal Customer   24  Business travel
# 39983    92358    satisfied    Male  disloyal Customer   30  Business travel
# 39984   101271    satisfied  Female  disloyal Customer   30  Business travel
# 39985    98848    satisfied    Male  disloyal Customer   30  Business travel
# ...        ...          ...     ...                ...  ...              ...
# 129871   91851    satisfied  Female  disloyal Customer   35  Personal Travel
# 129872   41573    satisfied  Female  disloyal Customer   69  Personal Travel
# 129873   46936    satisfied  Female  disloyal Customer   63  Personal Travel
# 129874   53969    satisfied  Female  disloyal Customer   11  Personal Travel
# 129875  119211    satisfied  Female  disloyal Customer   29  Personal Travel
#
# ...

# %%
airline_passenger_satisfaction[(airline_passenger_satisfaction['Satisfaction'] == 'satisfied') & (airline_passenger_satisfaction['Customer Type'] == 'Loyal Customer')]
# Out:
#             id Satisfaction  Gender   Customer Type  Age   Type of Travel  \
# 0        11112    satisfied  Female  Loyal Customer   65  Personal Travel
# 1       110278    satisfied    Male  Loyal Customer   47  Personal Travel
# 2       103199    satisfied  Female  Loyal Customer   15  Personal Travel
# 3        47462    satisfied  Female  Loyal Customer   60  Personal Travel
# 4       120011    satisfied  Female  Loyal Customer   70  Personal Travel
# ...        ...          ...     ...             ...  ...              ...
# 129674   17878    satisfied  Female  Loyal Customer   62  Personal Travel
# 129675   50870    satisfied  Female  Loyal Customer   17  Personal Travel
# 129676  118199    satisfied  Female  Loyal Customer   43  Personal Travel
# 129776  112487    satisfied    Male  Loyal Customer   61  Personal Travel
# 129777   88843    satisfied    Male  Loyal Customer   13  Personal Travel
#
#            Class  Flight Distance  Seat comfort  \
# ...

# %%
airline_passenger_satisfaction[(airline_passenger_satisfaction['Satisfaction'] == 'neutral or dissatisfied') & (airline_passenger_satisfaction['Customer Type'] == 'disloyal Customer')]
# Out:
#             id             Satisfaction  Gender      Customer Type  Age  \
# 40855    80426  neutral or dissatisfied    Male  disloyal Customer   22
# 40856    94293  neutral or dissatisfied  Female  disloyal Customer   48
# 40857   117437  neutral or dissatisfied  Female  disloyal Customer   44
# 40858    87035  neutral or dissatisfied    Male  disloyal Customer   40
# 40859    76367  neutral or dissatisfied  Female  disloyal Customer   39
# ...        ...                      ...     ...                ...  ...
# 129860   67201  neutral or dissatisfied  Female  disloyal Customer   43
# 129876   97768  neutral or dissatisfied    Male  disloyal Customer   63
# 129877  125368  neutral or dissatisfied    Male  disloyal Customer   69
# 129878     251  neutral or dissatisfied    Male  disloyal Customer   66
# 129879   84566  neutral or dissatisfied  Female  disloyal Customer   38
#
#          Type of Travel     Class  Flight Distance  Seat comfort  \
# ...

# %% [markdown]
# <h3 style='color: orange'>Unique value for each feature</h3>

# %%
uniqueValues = airline_passenger_satisfaction.nunique()
print('Count of unique value for each column:')
print(uniqueValues)
# Out:
# Count of unique value for each column:
# id                                   129880
# Satisfaction                              2
# Gender                                    2
# Customer Type                             2
# Age                                      75
# Type of Travel                            2
# Class                                     3
# Flight Distance                        5398
# Seat comfort                              6
# Departure/Arrival time convenient         6
# Food and drink                            6
# Gate location                             6
# Inflight wifi service                     6
# Inflight entertainment                    6
# Online support                            6
# Ease of Online booking                    6
# On-board service                          6
# Leg room service                          6
# Baggage handling                          5
# Checkin service                           6
# ...

# %% [markdown]
# <h3 style='color: orange'>Show count, unique, top, freq, mean, std, min, 25%, 50%, 75%, and max for each feature</h3>

# %%
airline_passenger_satisfaction.describe(include='all')
# Out:
#                    id Satisfaction  Gender   Customer Type            Age  \
# count   129880.000000       129880  129880          129880  129880.000000
# unique            NaN            2       2               2            NaN
# top               NaN    satisfied  Female  Loyal Customer            NaN
# freq              NaN        71087   65899          106100            NaN
# mean     64940.500000          NaN     NaN             NaN      39.427957
# std      37493.270818          NaN     NaN             NaN      15.119360
# min          1.000000          NaN     NaN             NaN       7.000000
# 25%      32470.750000          NaN     NaN             NaN      27.000000
# 50%      64940.500000          NaN     NaN             NaN      40.000000
# 75%      97410.250000          NaN     NaN             NaN      51.000000
# max     129880.000000          NaN     NaN             NaN      85.000000
#
#          Type of Travel     Class  Flight Distance   Seat comfort  \
# ...
